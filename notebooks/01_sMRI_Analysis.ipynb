# %% [markdown]
# # Structural MRI Analysis
#
# This notebook will be used for preprocessing and modeling our sMRI dataset.

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import cv2
import os

print("TensorFlow version:", tf.__version__)
